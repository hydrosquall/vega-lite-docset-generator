# %% [markdown]
# # build-vega-lite-docset
#
# > Converts a built copy of the vega-lite static Jekyll site to a docset directory

# %% [markdown]
# 1. Clone `vega-lite` as a sibling folder of this repository using the changes from [this PR](https://github.com/vega/vega-lite/pull/7642)
# 2. In that directory, run `yarn install && yarn docset`
# 3. In your python virtual environment, add these dependencies: `pip install bs4 lxml`
# 4. Using Jupyter is optional, but recommended for ease of debugging

# %%
# Make a folder to hold a copy of the built site
# !mkdir vega-lite-docs
# Out:
# mkdir: vega-lite-docs: File exists

# %%
# initial import of built site assets
# !rsync -r ../vega-lite/site/_site/* ./vega-lite-docs

# %%
import glob
import os
from urllib.parse import quote

import sqlite3

from bs4 import BeautifulSoup
from bs4.element import NavigableString

# %%
DEBUG = True

# %%
DOCSET_NAME = 'vega-lite'

# %%
DOCSET_PATH = f"{DOCSET_NAME}.docset/Contents/Resources/Documents/"

# %%
# Create a folder to hold your docset info
# !mkdir -p $DOCSET_PATH

# %%
VEGA_LITE_DOCSET = f"{DOCSET_NAME}.docset"
PLIST_PATH = f"{DOCSET_NAME}.docset/Contents/Info.plist"
SQLITE_PATH = f"{DOCSET_NAME}.docset/Contents/Resources/docSet.dsidx"

# %%
# Create Info.plist
docsetIndex = '''<?xml version="1.0" encoding="UTF-8"?>
<plist version="1.0">
  <dict>
    <key>CFBundleIdentifier</key>
    <string>vega-lite</string>
    <key>CFBundleName</key>
    <string>Vega-Lite</string>
    <key>DocSetPlatformFamily</key>
    <string>vega-lite</string>
    <key>isDashDocset</key>
    <true />
    <key>isJavaScriptEnabled</key>
    <true/>
    <key>dashIndexFilePath</key>
    <string>./index.html</string>
    <key>DashDocSetFallbackURL</key>
    <string>https://vega.github.io/vega-lite/</string>
    <key>DashDocSetPlayURL</key>
    <string>https://vega.github.io/editor/#/custom/vega-lite</string>
    <key>DashDocSetFamily</key>
<string>dashtoc</string>
  </dict>
</plist>
'''

with open('vega-lite.docset/Contents/Info.plist', 'w+') as fp:
    fp.write(docsetIndex)

# %%
# string to handle with replacement
DOCSET_BASE = 'DOCSET_BASE_TO_REPLACE'

def getDepthString(depth):
    return '.' + depth * "/.."


def update_relative_paths(filename):
    with open(filename) as fp:
        text = fp.read()
        
    depth = len(filename.split('/')) - 2
    depthString = getDepthString(depth)

    return text.replace(DOCSET_BASE, depthString)

# %%
# Convert absolute to relative URLs
matches = glob.glob(f"vega-lite-docs/**/*.html", recursive=True)
print(len(matches))
# now let's clean up the source files
for name in matches:
    if DEBUG:
        print('Moving relative urls', name)
    processed = update_relative_paths(name)
    with open(name, 'w') as fp:
        fp.write(processed)
# Out:
# 258
# Moving relative urls vega-lite-docs/index.html
# Moving relative urls vega-lite-docs/ecosystem.html
# Moving relative urls vega-lite-docs/applications.html
# Moving relative urls vega-lite-docs/comparison.html
# Moving relative urls vega-lite-docs/demo.html
# Moving relative urls vega-lite-docs/usage/compile.html
# Moving relative urls vega-lite-docs/usage/typescript.html
# Moving relative urls vega-lite-docs/usage/debugging.html
# Moving relative urls vega-lite-docs/usage/embed.html
# Moving relative urls vega-lite-docs/docs/sort.html
# Moving relative urls vega-lite-docs/docs/legend.html
# Moving relative urls vega-lite-docs/docs/mark.html
# Moving relative urls vega-lite-docs/docs/size.html
# Moving relative urls vega-lite-docs/docs/bin.html
# Moving relative urls vega-lite-docs/docs/datum.html
# Moving relative urls vega-lite-docs/docs/errorbar.html
# Moving relative urls vega-lite-docs/docs/format.html
# Moving relative urls vega-lite-docs/docs/text.html
# Moving relative urls vega-lite-docs/docs/image.html
# Moving relative urls vega-lite-docs/docs/density.html
# Moving relative urls vega-lite-docs/docs/band.html
# Moving relative urls vega-lite-docs/docs/window.html
# Moving relative urls vega-lite-docs/docs/label.html
# Moving relative urls vega-lite-docs/docs/index.html
# Moving relative urls vega-lite-docs/docs/geoshape.html
# Moving relative urls vega-lite-docs/docs/impute.html
# Moving relative urls vega-lite-docs/docs/joinaggregate.html
# Moving relative urls vega-lite-docs/docs/type.html
# Moving relative urls vega-lite-docs/docs/composition.html
# Moving relative urls vega-lite-docs/docs/transform.html
# Moving relative urls vega-lite-docs/docs/parameter.html
# Moving relative urls vega-lite-docs/docs/lookup.html
# Moving relative urls vega-lite-docs/docs/calculate.html
# Moving relative urls vega-lite-docs/docs/title.html
# Moving relative urls vega-lite-docs/docs/bind.html
# Moving relative urls vega-lite-docs/docs/selection.html
# Moving relative urls vega-lite-docs/docs/point.html
# Moving relative urls vega-lite-docs/docs/gradient.html
# Moving relative urls vega-lite-docs/docs/repeat.html
# Moving relative urls vega-lite-docs/docs/tick.html
# Moving relative urls vega-lite-docs/docs/axis.html
# Moving relative urls vega-lite-docs/docs/sample.html
# Moving relative urls vega-lite-docs/docs/flatten.html
# Moving relative urls vega-lite-docs/docs/aggregate.html
# Moving relative urls vega-lite-docs/docs/bar.html
# Moving relative urls vega-lite-docs/docs/data.html
# Moving relative urls vega-lite-docs/docs/pivot.html
# Moving relative urls vega-lite-docs/docs/predicate.html
# Moving relative urls vega-lite-docs/docs/trail.html
# Moving relative urls vega-lite-docs/docs/loess.html
# Moving relative urls vega-lite-docs/docs/facet.html
# Moving relative urls vega-lite-docs/docs/arc.html
# Moving relative urls vega-lite-docs/docs/area.html
# Moving relative urls vega-lite-docs/docs/circle.html
# Moving relative urls vega-lite-docs/docs/quantile.html
# Moving relative urls vega-lite-docs/docs/projection.html
# Moving relative urls vega-lite-docs/docs/boxplot.html
# Moving relative urls vega-lite-docs/docs/timeunit.html
# Moving relative urls vega-lite-docs/docs/config.html
# Moving relative urls vega-lite-docs/docs/rect.html
# Moving relative urls vega-lite-docs/docs/condition.html
# Moving relative urls vega-lite-docs/docs/types.html
# Moving relative urls vega-lite-docs/docs/tooltip.html
# Moving relative urls vega-lite-docs/docs/value.html
# Moving relative urls vega-lite-docs/docs/fold.html
# Moving relative urls vega-lite-docs/docs/field.html
# Moving relative urls vega-lite-docs/docs/encoding.html
# Moving relative urls vega-lite-docs/docs/datetime.html
# Moving relative urls vega-lite-docs/docs/concat.html
# Moving relative urls vega-lite-docs/docs/header.html
# Moving relative urls vega-lite-docs/docs/square.html
# Moving relative urls vega-lite-docs/docs/regression.html
# Moving relative urls vega-lite-docs/docs/errorband.html
# Moving relative urls vega-lite-docs/docs/spec.html
# Moving relative urls vega-lite-docs/docs/filter.html
# Moving relative urls vega-lite-docs/docs/scale.html
# Moving relative urls vega-lite-docs/docs/layer.html
# Moving relative urls vega-lite-docs/docs/rule.html
# Moving relative urls vega-lite-docs/docs/stack.html
# Moving relative urls vega-lite-docs/docs/line.html
# Moving relative urls vega-lite-docs/docs/resolve.html
# Moving relative urls vega-lite-docs/examples/trellis_area.html
# Moving relative urls vega-lite-docs/examples/interactive_paintbrush.html
# Moving relative urls vega-lite-docs/examples/layer_bar_labels.html
# Moving relative urls vega-lite-docs/examples/bar_layered_weather.html
# Moving relative urls vega-lite-docs/examples/point_href.html
# Moving relative urls vega-lite-docs/examples/arc_donut.html
# Moving relative urls vega-lite-docs/examples/layer_ranged_dot.html
# Moving relative urls vega-lite-docs/examples/interactive_bar_select_highlight.html
# Moving relative urls vega-lite-docs/examples/waterfall_chart.html
# Moving relative urls vega-lite-docs/examples/layer_point_errorbar_stdev.html
# Moving relative urls vega-lite-docs/examples/interactive_layered_crossfilter.html
# Moving relative urls vega-lite-docs/examples/layer_scatter_errorband_1D_stdev_global_mean.html
# Moving relative urls vega-lite-docs/examples/bar_argmax.html
# Moving relative urls vega-lite-docs/examples/nested_concat_align.html
# Moving relative urls vega-lite-docs/examples/isotype_bar_chart.html
# Moving relative urls vega-lite-docs/examples/window_top_k_others.html
# Moving relative urls vega-lite-docs/examples/layer_bar_labels_grey.html
# Moving relative urls vega-lite-docs/examples/point_invalid_color.html
# Moving relative urls vega-lite-docs/examples/trellis_stacked_bar.html
# Moving relative urls vega-lite-docs/examples/layer_point_line_loess.html
# Moving relative urls vega-lite-docs/examples/trellis_area_seattle.html
# Moving relative urls vega-lite-docs/examples/bar_diverging_stack_population_pyramid.html
# Moving relative urls vega-lite-docs/examples/area_density_stacked.html
# Moving relative urls vega-lite-docs/examples/layer_line_mean_point_raw.html
# Moving relative urls vega-lite-docs/examples/index.html
# Moving relative urls vega-lite-docs/examples/repeat_layer.html
# Moving relative urls vega-lite-docs/examples/point_quantile_quantile.html
# Moving relative urls vega-lite-docs/examples/line_conditional_axis.html
# Moving relative urls vega-lite-docs/examples/interactive_seattle_weather.html
# Moving relative urls vega-lite-docs/examples/layer_bar_fruit.html
# Moving relative urls vega-lite-docs/examples/geo_text.html
# Moving relative urls vega-lite-docs/examples/bar_aggregate_sort_by_encoding.html
# Moving relative urls vega-lite-docs/examples/lookup.html
# Moving relative urls vega-lite-docs/examples/selection_heatmap.html
# Moving relative urls vega-lite-docs/examples/sequence_line_fold.html
# Moving relative urls vega-lite-docs/examples/geo_choropleth.html
# Moving relative urls vega-lite-docs/examples/histogram_log.html
# Moving relative urls vega-lite-docs/examples/interactive_splom.html
# Moving relative urls vega-lite-docs/examples/line_step.html
# Moving relative urls vega-lite-docs/examples/stacked_area.html
# Moving relative urls vega-lite-docs/examples/bar_color_disabled_scale.html
# Moving relative urls vega-lite-docs/examples/trellis_bar.html
# Moving relative urls vega-lite-docs/examples/interactive_query_widgets.html
# Moving relative urls vega-lite-docs/examples/line_color.html
# Moving relative urls vega-lite-docs/examples/point_angle_windvector.html
# Moving relative urls vega-lite-docs/examples/stacked_area_stream.html
# Moving relative urls vega-lite-docs/examples/layer_precipitation_mean.html
# Moving relative urls vega-lite-docs/examples/line_dashed_part.html
# Moving relative urls vega-lite-docs/examples/joinaggregate_residual_graph.html
# Moving relative urls vega-lite-docs/examples/concat_population_pyramid.html
# Moving relative urls vega-lite-docs/examples/bar_month_temporal_initial.html
# Moving relative urls vega-lite-docs/examples/layer_candlestick.html
# Moving relative urls vega-lite-docs/examples/circle_github_punchcard.html
# Moving relative urls vega-lite-docs/examples/facet_bullet.html
# Moving relative urls vega-lite-docs/examples/interactive_legend.html
# Moving relative urls vega-lite-docs/examples/brush_table.html
# Moving relative urls vega-lite-docs/examples/layer_line_co2_concentration.html
# Moving relative urls vega-lite-docs/examples/interactive_multi_line_label.html
# Moving relative urls vega-lite-docs/examples/geo_repeat.html
# Moving relative urls vega-lite-docs/examples/bar_count_minimap.html
# Moving relative urls vega-lite-docs/examples/interactive_bin_extent.html
# Moving relative urls vega-lite-docs/examples/interactive_multi_line_pivot_tooltip.html
# Moving relative urls vega-lite-docs/examples/bar_axis_space_saving.html
# Moving relative urls vega-lite-docs/examples/layer_arc_label.html
# Moving relative urls vega-lite-docs/examples/stacked_area_normalize.html
# Moving relative urls vega-lite-docs/examples/window_top_k.html
# Moving relative urls vega-lite-docs/examples/area_density.html
# Moving relative urls vega-lite-docs/examples/point_bubble.html
# Moving relative urls vega-lite-docs/examples/window_rank.html
# Moving relative urls vega-lite-docs/examples/isotype_grid.html
# Moving relative urls vega-lite-docs/examples/concat_marginal_histograms.html
# Moving relative urls vega-lite-docs/examples/line_color_halo.html
# Moving relative urls vega-lite-docs/examples/trellis_scatter.html
# Moving relative urls vega-lite-docs/examples/geo_params_projections.html
# Moving relative urls vega-lite-docs/examples/geo_layer.html
# Moving relative urls vega-lite-docs/examples/point_2d.html
# Moving relative urls vega-lite-docs/examples/histogram_rel_freq.html
# Moving relative urls vega-lite-docs/examples/line_skip_invalid_mid_overlay.html
# Moving relative urls vega-lite-docs/examples/wheat_wages.html
# Moving relative urls vega-lite-docs/examples/tick_dot.html
# Moving relative urls vega-lite-docs/examples/layer_dual_axis.html
# Moving relative urls vega-lite-docs/examples/layer_histogram_global_mean.html
# Moving relative urls vega-lite-docs/examples/boxplot_preaggregated.html
# Moving relative urls vega-lite-docs/examples/text_scatterplot_colored.html
# Moving relative urls vega-lite-docs/examples/bar.html
# Moving relative urls vega-lite-docs/examples/rect_heatmap_weather.html
# Moving relative urls vega-lite-docs/examples/boxplot_2D_vertical.html
# Moving relative urls vega-lite-docs/examples/point_color_with_shape.html
# Moving relative urls vega-lite-docs/examples/bar_layered_transparent.html
# Moving relative urls vega-lite-docs/examples/layer_point_line_regression.html
# Moving relative urls vega-lite-docs/examples/stacked_bar_h.html
# Moving relative urls vega-lite-docs/examples/area_overlay.html
# Moving relative urls vega-lite-docs/examples/area_gradient.html
# Moving relative urls vega-lite-docs/examples/parallel_coordinate.html
# Moving relative urls vega-lite-docs/examples/interactive_concat_layer.html
# Moving relative urls vega-lite-docs/examples/geo_circle.html
# Moving relative urls vega-lite-docs/examples/geo_layer_line_london.html
# Moving relative urls vega-lite-docs/examples/stacked_bar_weather.html
# Moving relative urls vega-lite-docs/examples/layer_bar_annotations.html
# Moving relative urls vega-lite-docs/examples/trellis_bar_histogram.html
# Moving relative urls vega-lite-docs/examples/trail_color.html
# Moving relative urls vega-lite-docs/examples/area.html
# Moving relative urls vega-lite-docs/examples/circle.html
# Moving relative urls vega-lite-docs/examples/stacked_bar_count_corner_radius_mark.html
# Moving relative urls vega-lite-docs/examples/bar_aggregate.html
# Moving relative urls vega-lite-docs/examples/geo_trellis.html
# Moving relative urls vega-lite-docs/examples/interactive_global_development.html
# Moving relative urls vega-lite-docs/examples/window_percent_of_total.html
# Moving relative urls vega-lite-docs/examples/trail_comet.html
# Moving relative urls vega-lite-docs/examples/layer_line_errorband_ci.html
# Moving relative urls vega-lite-docs/examples/circle_binned.html
# Moving relative urls vega-lite-docs/examples/circle_natural_disasters.html
# Moving relative urls vega-lite-docs/examples/isotype_bar_chart_emoji.html
# Moving relative urls vega-lite-docs/examples/trellis_anscombe.html
# Moving relative urls vega-lite-docs/examples/layer_line_rolling_mean_point_raw.html
# Moving relative urls vega-lite-docs/examples/layer_likert.html
# Moving relative urls vega-lite-docs/examples/area_cumulative_freq.html
# Moving relative urls vega-lite-docs/examples/area_horizon.html
# Moving relative urls vega-lite-docs/examples/line_bump.html
# Moving relative urls vega-lite-docs/examples/tick_strip.html
# Moving relative urls vega-lite-docs/examples/layer_text_heatmap.html
# Moving relative urls vega-lite-docs/examples/bar_grouped.html
# Moving relative urls vega-lite-docs/examples/concat_layer_voyager_result.html
# Moving relative urls vega-lite-docs/examples/rect_binned_heatmap.html
# Moving relative urls vega-lite-docs/examples/line_strokedash.html
# Moving relative urls vega-lite-docs/examples/layer_point_errorbar_ci.html
# Moving relative urls vega-lite-docs/examples/bar_diverging_stack_transform.html
# Moving relative urls vega-lite-docs/examples/circle_wilkinson_dotplot.html
# Moving relative urls vega-lite-docs/examples/joinaggregate_mean_difference.html
# Moving relative urls vega-lite-docs/examples/line_slope.html
# Moving relative urls vega-lite-docs/examples/repeat_histogram.html
# Moving relative urls vega-lite-docs/examples/facet_grid_bar.html
# Moving relative urls vega-lite-docs/examples/interactive_multi_line_tooltip.html
# Moving relative urls vega-lite-docs/examples/layer_cumulative_histogram.html
# Moving relative urls vega-lite-docs/examples/arc_pie.html
# Moving relative urls vega-lite-docs/examples/bar_binned_data.html
# Moving relative urls vega-lite-docs/examples/selection_translate_scatterplot_drag.html
# Moving relative urls vega-lite-docs/examples/circle_custom_tick_labels.html
# Moving relative urls vega-lite-docs/examples/boxplot_minmax_2D_vertical.html
# Moving relative urls vega-lite-docs/examples/rect_mosaic_labelled_with_offset.html
# Moving relative urls vega-lite-docs/examples/interactive_line_hover.html
# Moving relative urls vega-lite-docs/examples/vconcat_weather.html
# Moving relative urls vega-lite-docs/examples/interactive_area_brush.html
# Moving relative urls vega-lite-docs/examples/airport_connections.html
# Moving relative urls vega-lite-docs/examples/bar_size_responsive.html
# Moving relative urls vega-lite-docs/examples/bar_negative.html
# Moving relative urls vega-lite-docs/examples/connected_scatterplot.html
# Moving relative urls vega-lite-docs/examples/bar_negative_horizontal_label.html
# Moving relative urls vega-lite-docs/examples/joinaggregate_mean_difference_by_year.html
# Moving relative urls vega-lite-docs/examples/geo_line.html
# Moving relative urls vega-lite-docs/examples/rect_lasagna.html
# Moving relative urls vega-lite-docs/examples/histogram.html
# Moving relative urls vega-lite-docs/examples/bar_gantt.html
# Moving relative urls vega-lite-docs/examples/stacked_bar_normalize.html
# Moving relative urls vega-lite-docs/examples/rect_heatmap.html
# Moving relative urls vega-lite-docs/examples/trellis_barley.html
# Moving relative urls vega-lite-docs/examples/geo_rule.html
# Moving relative urls vega-lite-docs/examples/area_density_facet.html
# Moving relative urls vega-lite-docs/examples/interactive_brush.html
# Moving relative urls vega-lite-docs/examples/layer_line_window.html
# Moving relative urls vega-lite-docs/examples/line_monotone.html
# Moving relative urls vega-lite-docs/examples/line_overlay_stroked.html
# Moving relative urls vega-lite-docs/examples/line_overlay.html
# Moving relative urls vega-lite-docs/examples/arc_radial.html
# Moving relative urls vega-lite-docs/examples/selection_layer_bar_month.html
# Moving relative urls vega-lite-docs/examples/layer_falkensee.html
# Moving relative urls vega-lite-docs/examples/scatter_image.html
# Moving relative urls vega-lite-docs/examples/circle_bubble_health_income.html
# Moving relative urls vega-lite-docs/examples/concat_bar_scales_discretize.html
# Moving relative urls vega-lite-docs/examples/interactive_index_chart.html
# Moving relative urls vega-lite-docs/examples/interactive_overview_detail.html
# Moving relative urls vega-lite-docs/examples/line.html
# Moving relative urls vega-lite-docs/examples/arc_pie_pyramid.html
# Moving relative urls vega-lite-docs/tutorials/streaming.html
# Moving relative urls vega-lite-docs/tutorials/figures.html
# Moving relative urls vega-lite-docs/tutorials/getting_started.html
# Moving relative urls vega-lite-docs/tutorials/explore.html

# %%
# Then get entries to add to the database
def get_soup(filename):
    with open(filename) as fp:
        text = fp.read()
    return BeautifulSoup(text, 'lxml')

# %%
def get_guide_entries():
    tutorial_soup = get_soup('vega-lite-docs/tutorials/getting_started.html')
    tutorial_links = tutorial_soup.find('section', {"class": "tutorials"}).find('nav').findAll('a')
    tutorial_entries = [
        [l.getText().strip(),
        'Guide',
        os.path.relpath(l['href'], '../')]
        for l in tutorial_links  
    ]
    
    usage_soup = get_soup('vega-lite-docs/usage/embed.html')
    usage_links = usage_soup.find('section', {"class": "usage"}).find('nav').findAll('a')
    usage_entries = [
        [f"Usage: {l.getText().strip()}",
        'Guide',
        os.path.relpath(l['href'], '../')]
        for l in usage_links  
    ]
    
    
    return [
        *tutorial_entries,
        *usage_entries,
        
        # other special entries
        ['Ecosystem', 'Guide', '/ecosystem.html'],
        ['Comparison', 'Guide', '/comparison.html'],
        #  ['Overview', 'Guide', '/index.html'],   # not needed, is main page
    ]

# %%
def get_sample_entries():
    examples_soup = get_soup('vega-lite-docs/examples/index.html')
    links = examples_soup.find('section', {"class": "examples"}).findAll('a', { "class": "imagegroup" })
    
    entries = [
        [f"{l.getText().strip()}",
        'Sample',
        os.path.relpath(l['href'], '../')]
        for l in links  
    ]
    
    return entries

# %%
# hardcoded remappings based on user testing, these can be revised later
# beautifulsoup tag
def clean_property_name(bsTag):
    maybeName = bsTag.getText().strip()
    
    if maybeName == 'Width / Height':
        return 'Size'
    
    return maybeName
    
def clean_category_name(bsTag):
    maybeName = " ".join(bsTag.getText().split("\w+/")).lower().strip()
    
    if maybeName == 'view specification':
        return 'view'
    
    return maybeName

# %%
def get_structures_entries():
    # TODO: see if this should get more granular eventually
    # decide on difference between top level spec and sub level properties
    docs_soup = get_soup('vega-lite-docs/docs/index.html')
    sidebar = docs_soup.find('aside', {"class": "page-sidebar"}).find('ul')
    cat_links = sidebar.findAll('li', { "class": "sidebar-nav-item" }, recursive=False) # don't go into sublists
    
    cat_entries = [
        [f"{l.getText().strip()}",
        'Category',
        os.path.relpath(l.findNext('a')['href'], '../')]
        for l in cat_links  
    ]
    
    # Children of each category
    structure_entries = []
    for category in cat_links:
        category_prefix = clean_category_name(category)
        
        sublist = None
        for sibling in category.next_siblings:
            if type(sibling) == NavigableString:
                continue
            sublist = sibling
            break
            
        # handle the random BR tags hanging out
        if sublist is None or sublist.name == 'br':
            continue
            

        if (sublist['class'] == ['sub-sub-nav']):
            category_properties = sublist.findAll('a')

            structure_entries.extend([
                [f"{category_prefix}.{clean_property_name(l)}",
                'Property',
                os.path.relpath(l['href'], '../')]
                for l in category_properties  
            ])
            
    return [
        *cat_entries,
        *structure_entries
    ]

# %%
all_entries = [*get_guide_entries(), *get_sample_entries(), *get_structures_entries()]

# %%
# Add 1 row
def addRow(cursor, name, rowType, path):
    statement = f"INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('{name}', '{rowType}', '{path}');"
    if DEBUG:
        print(statement)
    cursor.execute(statement)

# %%
try:
    # TODO: evaluate if this needs to become indempotent
    connection = sqlite3.connect(SQLITE_PATH)
    cursor = connection.cursor()
    
    # Uncomment these on first run
    #     cursor.execute('CREATE TABLE searchIndex(id INTEGER PRIMARY KEY, name TEXT, type TEXT, path TEXT);')
    #     cursor.execute('CREATE UNIQUE INDEX anchor ON searchIndex (name, type, path);')

    # Debug row
    #     addRow(cursor, 'Getting Started' ,'Guide', '/tutorials/getting_started.html#tutorial-overview')
    for entry in all_entries:
        addRow(cursor, *entry)
    
    connection.commit()
    
except sqlite3.Error as error:
    print("Error while executing sqlite script", error)
    
finally:
    if connection:
        connection.close()
        print('connection closed')
# Out:
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Getting Started', 'Guide', 'tutorials/getting_started.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Exploring Data', 'Guide', 'tutorials/explore.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Paper Figures', 'Guide', 'tutorials/figures.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Streaming Data', 'Guide', 'tutorials/streaming.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Usage: Embed', 'Guide', 'usage/embed.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Usage: Compile', 'Guide', 'usage/compile.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Usage: TypeScript', 'Guide', 'usage/typescript.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Usage: Debugging', 'Guide', 'usage/debugging.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Ecosystem', 'Guide', '/ecosystem.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Comparison', 'Guide', '/comparison.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Simple Bar Chart', 'Sample', 'examples/bar.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Responsive Bar Chart', 'Sample', 'examples/bar_size_responsive.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Aggregate Bar Chart', 'Sample', 'examples/bar_aggregate.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Aggregate Bar Chart (Sorted)', 'Sample', 'examples/bar_aggregate_sort_by_encoding.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Grouped Bar Chart', 'Sample', 'examples/bar_grouped.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Stacked Bar Chart', 'Sample', 'examples/stacked_bar_weather.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Stacked Bar Chart with Rounded Corners', 'Sample', 'examples/stacked_bar_count_corner_radius_mark.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Horizontal Stacked Bar Chart', 'Sample', 'examples/stacked_bar_h.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Normalized (Percentage) Stacked Bar Chart', 'Sample', 'examples/stacked_bar_normalize.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Gantt Chart (Ranged Bar Marks)', 'Sample', 'examples/bar_gantt.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('A Bar Chart Encoding Color Names in the Data', 'Sample', 'examples/bar_color_disabled_scale.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Layered Bar Chart', 'Sample', 'examples/bar_layered_transparent.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Diverging Stacked Bar Chart (Population Pyramid)', 'Sample', 'examples/bar_diverging_stack_population_pyramid.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Diverging Stacked Bar Chart (with Neutral Parts)', 'Sample', 'examples/bar_diverging_stack_transform.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Bar Chart with Labels', 'Sample', 'examples/layer_bar_labels.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Bar Chart with Label Overlays', 'Sample', 'examples/layer_bar_labels_grey.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Bar Chart showing Initials of Month Names', 'Sample', 'examples/bar_month_temporal_initial.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Bar Chart with Negative Values and a Zero-Baseline', 'Sample', 'examples/bar_negative.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Horizontal Bar Chart with Negative Values and Labels', 'Sample', 'examples/bar_negative_horizontal_label.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Bar Chart with a Spacing-Saving Y-Axis', 'Sample', 'examples/bar_axis_space_saving.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Histogram', 'Sample', 'examples/histogram.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Histogram (from Binned Data)', 'Sample', 'examples/bar_binned_data.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Log-scaled Histogram', 'Sample', 'examples/histogram_log.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Relative Frequency Histogram', 'Sample', 'examples/histogram_rel_freq.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Density Plot', 'Sample', 'examples/area_density.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Stacked Density Estimates', 'Sample', 'examples/area_density_stacked.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('2D Histogram Scatterplot', 'Sample', 'examples/circle_binned.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('2D Histogram Heatmap', 'Sample', 'examples/rect_binned_heatmap.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Cumulative Frequency Distribution', 'Sample', 'examples/area_cumulative_freq.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Layered Histogram and Cumulative Histogram', 'Sample', 'examples/layer_cumulative_histogram.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Wilkinson Dot Plot', 'Sample', 'examples/circle_wilkinson_dotplot.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Isotype Dot Plot', 'Sample', 'examples/isotype_bar_chart.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Isotype Dot Plot with Emoji', 'Sample', 'examples/isotype_bar_chart_emoji.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Scatterplot', 'Sample', 'examples/point_2d.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('1D Strip Plot', 'Sample', 'examples/tick_dot.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Strip Plot', 'Sample', 'examples/tick_strip.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Colored Scatterplot', 'Sample', 'examples/point_color_with_shape.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('2D Histogram Scatterplot', 'Sample', 'examples/circle_binned.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Bubble Plot', 'Sample', 'examples/point_bubble.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Scatterplot with Null Values in Grey', 'Sample', 'examples/point_invalid_color.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Scatterplot with Filled Circles', 'Sample', 'examples/circle.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Bubble Plot (Gapminder)', 'Sample', 'examples/circle_bubble_health_income.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Bubble Plot (Natural Disasters)', 'Sample', 'examples/circle_natural_disasters.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Scatter Plot with Text Marks', 'Sample', 'examples/text_scatterplot_colored.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Image-based Scatter Plot', 'Sample', 'examples/scatter_image.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Strip plot with custom axis tick labels', 'Sample', 'examples/circle_custom_tick_labels.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Line Chart', 'Sample', 'examples/line.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Line Chart with Point Markers', 'Sample', 'examples/line_overlay.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Line Chart with Stroked Point Markers', 'Sample', 'examples/line_overlay_stroked.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Multi Series Line Chart', 'Sample', 'examples/line_color.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Multi Series Line Chart with Repeat Operator', 'Sample', 'examples/repeat_layer.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Multi Series Line Chart with Halo Stroke', 'Sample', 'examples/line_color_halo.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Slope Graph', 'Sample', 'examples/line_slope.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Step Chart', 'Sample', 'examples/line_step.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Line Chart with Monotone Interpolation', 'Sample', 'examples/line_monotone.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Line Chart with Conditional Axis Properties', 'Sample', 'examples/line_conditional_axis.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Connected Scatterplot (Lines with Custom Paths)', 'Sample', 'examples/connected_scatterplot.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Bump Chart', 'Sample', 'examples/line_bump.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Line Chart with Varying Size (using the trail mark)', 'Sample', 'examples/trail_color.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('A comet chart showing changes between between two states', 'Sample', 'examples/trail_comet.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Line Chart with Markers and Invalid Values', 'Sample', 'examples/line_skip_invalid_mid_overlay.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Carbon Dioxide in the Atmosphere', 'Sample', 'examples/layer_line_co2_concentration.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Line Charts Showing Ranks Over Time', 'Sample', 'examples/window_rank.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Drawing Sine and Cosine Curves with the Sequence Generator', 'Sample', 'examples/sequence_line_fold.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Line chart with varying stroke dash', 'Sample', 'examples/line_strokedash.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Line chart with a dashed part', 'Sample', 'examples/line_dashed_part.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Area Chart', 'Sample', 'examples/area.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Area Chart with Gradient', 'Sample', 'examples/area_gradient.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Area Chart with Overlaying Lines and Point Markers', 'Sample', 'examples/area_overlay.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Stacked Area Chart', 'Sample', 'examples/stacked_area.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Normalized Stacked Area Chart', 'Sample', 'examples/stacked_area_normalize.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Streamgraph', 'Sample', 'examples/stacked_area_stream.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Horizon Graph', 'Sample', 'examples/area_horizon.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Table Heatmap', 'Sample', 'examples/rect_heatmap.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Annual Weather Heatmap', 'Sample', 'examples/rect_heatmap_weather.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('2D Histogram Heatmap', 'Sample', 'examples/rect_binned_heatmap.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Table Bubble Plot (Github Punch Card)', 'Sample', 'examples/circle_github_punchcard.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Heatmap with Labels', 'Sample', 'examples/layer_text_heatmap.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Lasagna Plot (Dense Time-Series Heatmap)', 'Sample', 'examples/rect_lasagna.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Mosaic Chart with Labels', 'Sample', 'examples/rect_mosaic_labelled_with_offset.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Wind Vector Map', 'Sample', 'examples/point_angle_windvector.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Pie Chart', 'Sample', 'examples/arc_pie.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Donut Chart', 'Sample', 'examples/arc_donut.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Pie Chart with Labels', 'Sample', 'examples/layer_arc_label.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Radial Plot', 'Sample', 'examples/arc_radial.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Pyramid Pie Chart', 'Sample', 'examples/arc_pie_pyramid.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Calculate Percentage of Total', 'Sample', 'examples/window_percent_of_total.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Calculate Difference from Average', 'Sample', 'examples/joinaggregate_mean_difference.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Calculate Difference from Annual Average', 'Sample', 'examples/joinaggregate_mean_difference_by_year.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Calculate Residuals', 'Sample', 'examples/joinaggregate_residual_graph.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Line Charts Showing Ranks Over Time', 'Sample', 'examples/window_rank.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Waterfall Chart of Monthly Profit and Loss', 'Sample', 'examples/waterfall_chart.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Filtering Top-K Items', 'Sample', 'examples/window_top_k.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Top-K Plot with “Others”', 'Sample', 'examples/window_top_k_others.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Using the lookup transform to combine data', 'Sample', 'examples/lookup.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Cumulative Frequency Distribution', 'Sample', 'examples/area_cumulative_freq.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Layered Histogram and Cumulative Histogram', 'Sample', 'examples/layer_cumulative_histogram.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Parallel Coordinate Plot', 'Sample', 'examples/parallel_coordinate.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Bar Chart Showing Argmax Value', 'Sample', 'examples/bar_argmax.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Layering Averages over Raw Values', 'Sample', 'examples/layer_line_mean_point_raw.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Layering Rolling Averages over Raw Values', 'Sample', 'examples/layer_line_rolling_mean_point_raw.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Line Chart to Show Benchmarking Results', 'Sample', 'examples/layer_line_window.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Quantile-Quantile Plot (QQ Plot)', 'Sample', 'examples/point_quantile_quantile.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Linear Regression', 'Sample', 'examples/layer_point_line_regression.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Loess Regression', 'Sample', 'examples/layer_point_line_loess.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Error Bars Showing Confidence Interval', 'Sample', 'examples/layer_point_errorbar_ci.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Error Bars Showing Standard Deviation', 'Sample', 'examples/layer_point_errorbar_stdev.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Line Chart with Confidence Interval Band', 'Sample', 'examples/layer_line_errorband_ci.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Scatterplot with Mean and Standard Deviation Overlay', 'Sample', 'examples/layer_scatter_errorband_1D_stdev_global_mean.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Box Plot with Min/Max Whiskers', 'Sample', 'examples/boxplot_minmax_2D_vertical.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Tukey Box Plot (1.5 IQR)', 'Sample', 'examples/boxplot_2D_vertical.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Box Plot with Pre-Calculated Summaries', 'Sample', 'examples/boxplot_preaggregated.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Simple Bar Chart with Labels', 'Sample', 'examples/layer_bar_labels.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Simple Bar Chart with Labels and Emojis', 'Sample', 'examples/layer_bar_fruit.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Layering text over heatmap', 'Sample', 'examples/layer_text_heatmap.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Carbon Dioxide in the Atmosphere', 'Sample', 'examples/layer_line_co2_concentration.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Bar Chart Highlighting Values beyond a Threshold', 'Sample', 'examples/layer_bar_annotations.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Mean overlay over precipitation chart', 'Sample', 'examples/layer_precipitation_mean.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Histogram with a Global Mean Overlay', 'Sample', 'examples/layer_histogram_global_mean.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Line Chart with Highlighted Rectangles', 'Sample', 'examples/layer_falkensee.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Layering Averages over Raw Values', 'Sample', 'examples/layer_line_mean_point_raw.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Layering Rolling Averages over Raw Values', 'Sample', 'examples/layer_line_rolling_mean_point_raw.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Distributions and Medians of Likert Scale Ratings', 'Sample', 'examples/layer_likert.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Comparative Likert Scale Ratings', 'Sample', 'examples/concat_layer_voyager_result.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Candlestick Chart', 'Sample', 'examples/layer_candlestick.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Ranged Dot Plot', 'Sample', 'examples/layer_ranged_dot.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Bullet Chart', 'Sample', 'examples/facet_bullet.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Layered Plot with Dual-Axis', 'Sample', 'examples/layer_dual_axis.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Horizon Graph', 'Sample', 'examples/area_horizon.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Weekly Weather Plot', 'Sample', 'examples/bar_layered_weather.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Wheat and Wages Example', 'Sample', 'examples/wheat_wages.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Trellis Bar Chart', 'Sample', 'examples/trellis_bar.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Trellis Stacked Bar Chart', 'Sample', 'examples/trellis_stacked_bar.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Trellis Scatter Plot (wrapped)', 'Sample', 'examples/trellis_scatter.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Trellis Histograms', 'Sample', 'examples/trellis_bar_histogram.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Trellis Scatter Plot Showing Anscombe’s Quartet', 'Sample', 'examples/trellis_anscombe.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Becker’s Barley Trellis Plot', 'Sample', 'examples/trellis_barley.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Trellis Area', 'Sample', 'examples/trellis_area.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Trellis Area Plot Showing Annual Temperatures in Seattle', 'Sample', 'examples/trellis_area_seattle.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Faceted Density Plot', 'Sample', 'examples/area_density_facet.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Compact Trellis Grid of Bar Charts', 'Sample', 'examples/facet_grid_bar.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Repeat and Layer to Show Different Movie Measures', 'Sample', 'examples/repeat_layer.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Vertical Concatenation', 'Sample', 'examples/vconcat_weather.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Horizontally Repeated Charts', 'Sample', 'examples/repeat_histogram.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Interactive Scatterplot Matrix', 'Sample', 'examples/interactive_splom.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Marginal Histograms', 'Sample', 'examples/concat_marginal_histograms.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Discretizing scales', 'Sample', 'examples/concat_bar_scales_discretize.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Nested View Concatenation Aligned with Axis minExtent', 'Sample', 'examples/nested_concat_align.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Population Pyramid', 'Sample', 'examples/concat_population_pyramid.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Choropleth of Unemployment Rate per County', 'Sample', 'examples/geo_choropleth.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('One Dot per Zipcode in the U.S.', 'Sample', 'examples/geo_circle.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('One Dot per Airport in the U.S. Overlayed on Geoshape', 'Sample', 'examples/geo_layer.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Rules (line segments) Connecting SEA to every Airport Reachable via Direct Flights', 'Sample', 'examples/geo_rule.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Three Choropleths Representing Disjoint Data from the Same Table', 'Sample', 'examples/geo_repeat.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('U.S. State Capitals Overlayed on a Map of U.S.', 'Sample', 'examples/geo_text.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Line between Airports in the U.S.', 'Sample', 'examples/geo_line.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Income in the U.S. by State, Faceted over Income Brackets', 'Sample', 'examples/geo_trellis.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('London Tube Lines', 'Sample', 'examples/geo_layer_line_london.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Projection explorer', 'Sample', 'examples/geo_params_projections.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Bar Chart with Highlighting on Hover and Selection on Click', 'Sample', 'examples/interactive_bar_select_highlight.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Interactive Legend', 'Sample', 'examples/interactive_legend.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Scatterplot with External Links and Tooltips', 'Sample', 'examples/point_href.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Rectangular Brush', 'Sample', 'examples/interactive_brush.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Area Chart with Rectangular Brush', 'Sample', 'examples/interactive_area_brush.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Paintbrush Highlight', 'Sample', 'examples/interactive_paintbrush.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Scatterplot Pan & Zoom', 'Sample', 'examples/selection_translate_scatterplot_drag.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Query Widgets', 'Sample', 'examples/interactive_query_widgets.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Interactive Average', 'Sample', 'examples/selection_layer_bar_month.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Multi Series Line Chart with Interactive Highlight', 'Sample', 'examples/interactive_line_hover.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Multi Series Line Chart with Labels', 'Sample', 'examples/interactive_multi_line_label.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Multi Series Line Chart with Tooltip', 'Sample', 'examples/interactive_multi_line_pivot_tooltip.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Multi Series Line Chart with Tooltip', 'Sample', 'examples/interactive_multi_line_tooltip.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Isotype Grid', 'Sample', 'examples/isotype_grid.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Brushing Scatter Plot to show data on a table', 'Sample', 'examples/brush_table.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Selectable Heatmap', 'Sample', 'examples/selection_heatmap.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Bar Chart with a Minimap', 'Sample', 'examples/bar_count_minimap.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Interactive Index Chart', 'Sample', 'examples/interactive_index_chart.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Focus + Context - Smooth Histogram Zooming', 'Sample', 'examples/interactive_bin_extent.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Overview and Detail', 'Sample', 'examples/interactive_overview_detail.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Crossfilter', 'Sample', 'examples/interactive_layered_crossfilter.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Interactive Scatterplot Matrix', 'Sample', 'examples/interactive_splom.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Interactive Dashboard with Cross Highlight', 'Sample', 'examples/interactive_concat_layer.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Seattle Weather Exploration', 'Sample', 'examples/interactive_seattle_weather.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Connections among Major U.S. Airports.', 'Sample', 'examples/airport_connections.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('An interactive scatter plot of global health statistics by country and year.', 'Sample', 'examples/interactive_global_development.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Overview', 'Category', 'docs');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('View Specification', 'Category', 'docs/spec.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Data / Datasets', 'Category', 'docs/data.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Transform', 'Category', 'docs/transform.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Mark', 'Category', 'docs/mark.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Encoding', 'Category', 'docs/encoding.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Projection', 'Category', 'docs/projection.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('View Composition', 'Category', 'docs/composition.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Parameter', 'Category', 'docs/parameter.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Config', 'Category', 'docs/config.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Property Types', 'Category', 'docs/types.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Tooltip', 'Category', 'docs/tooltip.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('view.Title', 'Property', 'docs/title.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('view.Size', 'Property', 'docs/size.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.Aggregate', 'Property', 'docs/aggregate.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.Bin', 'Property', 'docs/bin.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.Calculate', 'Property', 'docs/calculate.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.Density', 'Property', 'docs/density.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.Filter', 'Property', 'docs/filter.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.Flatten', 'Property', 'docs/flatten.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.Fold', 'Property', 'docs/fold.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.Impute', 'Property', 'docs/impute.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.Join Aggregate', 'Property', 'docs/joinaggregate.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.Loess', 'Property', 'docs/loess.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.Lookup', 'Property', 'docs/lookup.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.Pivot', 'Property', 'docs/pivot.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.Quantile', 'Property', 'docs/quantile.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.Regression', 'Property', 'docs/regression.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.Sample', 'Property', 'docs/sample.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.Stack', 'Property', 'docs/stack.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.Time Unit', 'Property', 'docs/timeunit.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.Window', 'Property', 'docs/window.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.Arc', 'Property', 'docs/arc.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.Area', 'Property', 'docs/area.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.Bar', 'Property', 'docs/bar.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.Box Plot', 'Property', 'docs/boxplot.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.Circle', 'Property', 'docs/circle.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.Error Band', 'Property', 'docs/errorband.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.Error Bar', 'Property', 'docs/errorbar.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.Geoshape', 'Property', 'docs/geoshape.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.Image', 'Property', 'docs/image.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.Line', 'Property', 'docs/line.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.Point', 'Property', 'docs/point.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.Rect', 'Property', 'docs/rect.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.Rule', 'Property', 'docs/rule.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.Square', 'Property', 'docs/square.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.Text', 'Property', 'docs/text.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.Tick', 'Property', 'docs/tick.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.Trail', 'Property', 'docs/trail.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('encoding.Aggregate', 'Property', 'docs/aggregate.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('encoding.Axis', 'Property', 'docs/axis.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('encoding.Band', 'Property', 'docs/band.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('encoding.Bin', 'Property', 'docs/bin.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('encoding.Condition', 'Property', 'docs/condition.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('encoding.Datum', 'Property', 'docs/datum.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('encoding.Field', 'Property', 'docs/field.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('encoding.Format', 'Property', 'docs/format.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('encoding.Header', 'Property', 'docs/header.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('encoding.Impute', 'Property', 'docs/impute.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('encoding.Legend', 'Property', 'docs/legend.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('encoding.Scale', 'Property', 'docs/scale.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('encoding.Stack', 'Property', 'docs/stack.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('encoding.Sort', 'Property', 'docs/sort.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('encoding.Time Unit', 'Property', 'docs/timeunit.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('encoding.Type', 'Property', 'docs/type.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('encoding.Value', 'Property', 'docs/value.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('view composition.Facet', 'Property', 'docs/facet.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('view composition.Layer', 'Property', 'docs/layer.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('view composition.Concat', 'Property', 'docs/concat.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('view composition.Repeat', 'Property', 'docs/repeat.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('view composition.Resolve', 'Property', 'docs/resolve.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('parameter.Value', 'Property', 'docs/value.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('parameter.Expr', 'Property', 'docs/parameter.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('parameter.Bind', 'Property', 'docs/bind.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('parameter.Select', 'Property', 'docs/selection.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('property types.Date Time', 'Property', 'docs/datetime.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('property types.Gradient', 'Property', 'docs/gradient.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('property types.Predicate', 'Property', 'docs/predicate.html');
# connection closed

# %%
# logos from https://github.com/vega/logos
#!curl https://github.com/vega/logos/raw/master/assets/VL_Color%40128.png > 
# !cp img/* $VEGA_LITE_DOCSET/

# %%
def enrich_table_of_contents(filename):
    with open(filename) as fp:
        text = fp.read()
        
    # get the soup
    soup = BeautifulSoup(text, 'lxml')
    content = soup.find('section', {"class": 'page-content'}) or soup.find('div', {"class": 'page-content'})
    
    if content is None:
        return text
        
    category_anchors = content.findAll('h2')
    for anchor in category_anchors:

        if anchor.find('a'):
            continue
        # safe quote to handle / path characters
        # https://stackoverflow.com/questions/1695183/how-to-percent-encode-url-parameters-in-python
        safeName = quote(anchor.getText().strip(), safe='')
        dashAnchor = soup.new_tag('a')
        dashAnchor['name'] = f'//apple_ref/cpp/Category/{safeName}'
        dashAnchor['class'] = 'dashAnchor'
        anchor.append(dashAnchor)
    
    section_anchors = content.findAll('h3')
    for anchor in section_anchors:

        if anchor.find('a'):
            continue
            
        safeName = quote(anchor.getText().strip(), safe='')
        dashAnchor = soup.new_tag('a')
        dashAnchor['name'] = f'//apple_ref/cpp/Section/{safeName}'
        dashAnchor['class'] = 'dashAnchor'
        anchor.append(dashAnchor)

        
    print("Added", len(section_anchors), 'sections', len(category_anchors), 'categories')
    
    return str(soup)

# %%
# URL encode strings
#quote("Programming / Data", safe='')

# %%
def remove_page_elements(filename):
    with open(filename) as fp:
        text = fp.read()

    # remove sidebar nav elements
    soup = BeautifulSoup(text, 'lxml')
    sidebar = soup.find('aside', {"class": "page-sidebar"})
    
    if sidebar:
        print("removing sidebar from ", filename)
        sidebar.decompose()
    
    return str(soup)

# %%
# Add "toc" entries for each page.
matches = glob.glob(f"vega-lite-docs/**/*.html", recursive=True)
print(len(matches))

for name in matches:
    if DEBUG:
        print('Enrich table of contents', name)
    processed = enrich_table_of_contents(name)
    
    with open(name, 'w') as fp:
        fp.write(processed)
# Out:
# 258
# Enrich table of contents vega-lite-docs/index.html
# Added 0 sections 4 categories
# Enrich table of contents vega-lite-docs/ecosystem.html
# Added 0 sections 6 categories
# Enrich table of contents vega-lite-docs/applications.html
# Enrich table of contents vega-lite-docs/comparison.html
# Added 0 sections 3 categories
# Enrich table of contents vega-lite-docs/demo.html
# Enrich table of contents vega-lite-docs/usage/compile.html
# Added 4 sections 2 categories
# Enrich table of contents vega-lite-docs/usage/typescript.html
# Added 0 sections 0 categories
# Enrich table of contents vega-lite-docs/usage/debugging.html
# Added 0 sections 4 categories
# Enrich table of contents vega-lite-docs/usage/embed.html
# Added 3 sections 2 categories
# Enrich table of contents vega-lite-docs/docs/sort.html
# Added 5 sections 3 categories
# Enrich table of contents vega-lite-docs/docs/legend.html
# Added 6 sections 4 categories
# Enrich table of contents vega-lite-docs/docs/mark.html
# Added 6 sections 5 categories
# Enrich table of contents vega-lite-docs/docs/size.html
# Added 5 sections 3 categories
# Enrich table of contents vega-lite-docs/docs/bin.html
# Added 6 sections 5 categories
# Enrich table of contents vega-lite-docs/docs/datum.html
# Added 2 sections 1 categories
# Enrich table of contents vega-lite-docs/docs/errorbar.html
# Added 0 sections 9 categories
# Enrich table of contents vega-lite-docs/docs/format.html
# Added 2 sections 2 categories
# Enrich table of contents vega-lite-docs/docs/text.html
# Added 4 sections 4 categories
# Enrich table of contents vega-lite-docs/docs/image.html
# Added 1 sections 4 categories
# Enrich table of contents vega-lite-docs/docs/density.html
# Added 3 sections 2 categories
# Enrich table of contents vega-lite-docs/docs/band.html
# Added 1 sections 1 categories
# Enrich table of contents vega-lite-docs/docs/window.html
# Added 7 sections 6 categories
# Enrich table of contents vega-lite-docs/docs/label.html
# Added 0 sections 0 categories
# Enrich table of contents vega-lite-docs/docs/index.html
# Added 0 sections 1 categories
# Enrich table of contents vega-lite-docs/docs/geoshape.html
# Added 0 sections 1 categories
# Enrich table of contents vega-lite-docs/docs/impute.html
# Added 1 sections 3 categories
# Enrich table of contents vega-lite-docs/docs/joinaggregate.html
# Added 4 sections 4 categories
# Enrich table of contents vega-lite-docs/docs/type.html
# Added 2 sections 5 categories
# Enrich table of contents vega-lite-docs/docs/composition.html
# Added 0 sections 6 categories
# Enrich table of contents vega-lite-docs/docs/transform.html
# Added 0 sections 1 categories
# Enrich table of contents vega-lite-docs/docs/parameter.html
# Added 5 sections 4 categories
# Enrich table of contents vega-lite-docs/docs/lookup.html
# Added 2 sections 1 categories
# Enrich table of contents vega-lite-docs/docs/calculate.html
# Added 0 sections 2 categories
# Enrich table of contents vega-lite-docs/docs/title.html
# Added 0 sections 2 categories
# Enrich table of contents vega-lite-docs/docs/bind.html
# Added 0 sections 3 categories
# Enrich table of contents vega-lite-docs/docs/selection.html
# Added 10 sections 4 categories
# Enrich table of contents vega-lite-docs/docs/point.html
# Added 6 sections 4 categories
# Enrich table of contents vega-lite-docs/docs/gradient.html
# Added 1 sections 3 categories
# Enrich table of contents vega-lite-docs/docs/repeat.html
# Added 4 sections 6 categories
# Enrich table of contents vega-lite-docs/docs/tick.html
# Added 2 sections 4 categories
# Enrich table of contents vega-lite-docs/docs/axis.html
# Added 8 sections 3 categories
# Enrich table of contents vega-lite-docs/docs/sample.html
# Added 0 sections 3 categories
# Enrich table of contents vega-lite-docs/docs/flatten.html
# Added 2 sections 3 categories
# Enrich table of contents vega-lite-docs/docs/aggregate.html
# Added 2 sections 5 categories
# Enrich table of contents vega-lite-docs/docs/bar.html
# Added 13 sections 4 categories
# Enrich table of contents vega-lite-docs/docs/data.html
# Added 11 sections 5 categories
# Enrich table of contents vega-lite-docs/docs/pivot.html
# Added 0 sections 3 categories
# Enrich table of contents vega-lite-docs/docs/predicate.html
# Added 8 sections 3 categories
# Enrich table of contents vega-lite-docs/docs/trail.html
# Added 2 sections 4 categories
# Enrich table of contents vega-lite-docs/docs/loess.html
# Added 0 sections 3 categories
# Enrich table of contents vega-lite-docs/docs/facet.html
# Added 6 sections 5 categories
# Enrich table of contents vega-lite-docs/docs/arc.html
# Added 1 sections 4 categories
# Enrich table of contents vega-lite-docs/docs/area.html
# Added 6 sections 4 categories
# Enrich table of contents vega-lite-docs/docs/circle.html
# Added 1 sections 3 categories
# Enrich table of contents vega-lite-docs/docs/quantile.html
# Added 1 sections 2 categories
# Enrich table of contents vega-lite-docs/docs/projection.html
# Added 0 sections 4 categories
# Enrich table of contents vega-lite-docs/docs/boxplot.html
# Added 0 sections 9 categories
# Enrich table of contents vega-lite-docs/docs/timeunit.html
# Added 5 sections 5 categories
# Enrich table of contents vega-lite-docs/docs/config.html
# Added 5 sections 12 categories
# Enrich table of contents vega-lite-docs/docs/rect.html
# Added 2 sections 4 categories
# Enrich table of contents vega-lite-docs/docs/condition.html
# Added 0 sections 2 categories
# Enrich table of contents vega-lite-docs/docs/types.html
# Added 11 sections 3 categories
# Enrich table of contents vega-lite-docs/docs/tooltip.html
# Added 0 sections 6 categories
# Enrich table of contents vega-lite-docs/docs/value.html
# Added 0 sections 0 categories
# Enrich table of contents vega-lite-docs/docs/fold.html
# Added 0 sections 3 categories
# Enrich table of contents vega-lite-docs/docs/field.html
# Added 0 sections 0 categories
# Enrich table of contents vega-lite-docs/docs/encoding.html
# Added 16 sections 13 categories
# Enrich table of contents vega-lite-docs/docs/datetime.html
# Added 0 sections 0 categories
# Enrich table of contents vega-lite-docs/docs/concat.html
# Added 3 sections 6 categories
# Enrich table of contents vega-lite-docs/docs/header.html
# Added 4 sections 3 categories
# Enrich table of contents vega-lite-docs/docs/square.html
# Added 0 sections 3 categories
# Enrich table of contents vega-lite-docs/docs/regression.html
# Added 0 sections 3 categories
# Enrich table of contents vega-lite-docs/docs/errorband.html
# Added 0 sections 10 categories
# Enrich table of contents vega-lite-docs/docs/spec.html
# Added 1 sections 6 categories
# Enrich table of contents vega-lite-docs/docs/filter.html
# Added 0 sections 0 categories
# Enrich table of contents vega-lite-docs/docs/scale.html
# Added 21 sections 10 categories
# Enrich table of contents vega-lite-docs/docs/layer.html
# Added 1 sections 1 categories
# Enrich table of contents vega-lite-docs/docs/rule.html
# Added 2 sections 4 categories
# Enrich table of contents vega-lite-docs/docs/stack.html
# Added 10 sections 3 categories
# Enrich table of contents vega-lite-docs/docs/line.html
# Added 9 sections 4 categories
# Enrich table of contents vega-lite-docs/docs/resolve.html
# Added 0 sections 1 categories
# Enrich table of contents vega-lite-docs/examples/trellis_area.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/interactive_paintbrush.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_bar_labels.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/bar_layered_weather.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/point_href.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/arc_donut.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_ranged_dot.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/interactive_bar_select_highlight.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/waterfall_chart.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_point_errorbar_stdev.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/interactive_layered_crossfilter.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_scatter_errorband_1D_stdev_global_mean.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/bar_argmax.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/nested_concat_align.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/isotype_bar_chart.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/window_top_k_others.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_bar_labels_grey.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/point_invalid_color.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/trellis_stacked_bar.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_point_line_loess.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/trellis_area_seattle.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/bar_diverging_stack_population_pyramid.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/area_density_stacked.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_line_mean_point_raw.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/index.html
# Added 16 sections 7 categories
# Enrich table of contents vega-lite-docs/examples/repeat_layer.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/point_quantile_quantile.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/line_conditional_axis.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/interactive_seattle_weather.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_bar_fruit.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/geo_text.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/bar_aggregate_sort_by_encoding.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/lookup.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/selection_heatmap.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/sequence_line_fold.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/geo_choropleth.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/histogram_log.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/interactive_splom.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/line_step.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/stacked_area.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/bar_color_disabled_scale.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/trellis_bar.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/interactive_query_widgets.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/line_color.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/point_angle_windvector.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/stacked_area_stream.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_precipitation_mean.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/line_dashed_part.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/joinaggregate_residual_graph.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/concat_population_pyramid.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/bar_month_temporal_initial.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_candlestick.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/circle_github_punchcard.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/facet_bullet.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/interactive_legend.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/brush_table.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_line_co2_concentration.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/interactive_multi_line_label.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/geo_repeat.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/bar_count_minimap.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/interactive_bin_extent.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/interactive_multi_line_pivot_tooltip.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/bar_axis_space_saving.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_arc_label.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/stacked_area_normalize.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/window_top_k.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/area_density.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/point_bubble.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/window_rank.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/isotype_grid.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/concat_marginal_histograms.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/line_color_halo.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/trellis_scatter.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/geo_params_projections.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/geo_layer.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/point_2d.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/histogram_rel_freq.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/line_skip_invalid_mid_overlay.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/wheat_wages.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/tick_dot.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_dual_axis.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_histogram_global_mean.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/boxplot_preaggregated.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/text_scatterplot_colored.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/bar.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/rect_heatmap_weather.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/boxplot_2D_vertical.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/point_color_with_shape.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/bar_layered_transparent.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_point_line_regression.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/stacked_bar_h.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/area_overlay.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/area_gradient.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/parallel_coordinate.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/interactive_concat_layer.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/geo_circle.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/geo_layer_line_london.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/stacked_bar_weather.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_bar_annotations.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/trellis_bar_histogram.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/trail_color.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/area.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/circle.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/stacked_bar_count_corner_radius_mark.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/bar_aggregate.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/geo_trellis.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/interactive_global_development.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/window_percent_of_total.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/trail_comet.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_line_errorband_ci.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/circle_binned.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/circle_natural_disasters.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/isotype_bar_chart_emoji.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/trellis_anscombe.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_line_rolling_mean_point_raw.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_likert.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/area_cumulative_freq.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/area_horizon.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/line_bump.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/tick_strip.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_text_heatmap.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/bar_grouped.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/concat_layer_voyager_result.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/rect_binned_heatmap.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/line_strokedash.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_point_errorbar_ci.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/bar_diverging_stack_transform.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/circle_wilkinson_dotplot.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/joinaggregate_mean_difference.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/line_slope.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/repeat_histogram.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/facet_grid_bar.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/interactive_multi_line_tooltip.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_cumulative_histogram.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/arc_pie.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/bar_binned_data.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/selection_translate_scatterplot_drag.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/circle_custom_tick_labels.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/boxplot_minmax_2D_vertical.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/rect_mosaic_labelled_with_offset.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/interactive_line_hover.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/vconcat_weather.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/interactive_area_brush.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/airport_connections.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/bar_size_responsive.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/bar_negative.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/connected_scatterplot.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/bar_negative_horizontal_label.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/joinaggregate_mean_difference_by_year.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/geo_line.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/rect_lasagna.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/histogram.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/bar_gantt.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/stacked_bar_normalize.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/rect_heatmap.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/trellis_barley.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/geo_rule.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/area_density_facet.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/interactive_brush.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_line_window.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/line_monotone.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/line_overlay_stroked.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/line_overlay.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/arc_radial.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/selection_layer_bar_month.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/layer_falkensee.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/scatter_image.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/circle_bubble_health_income.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/concat_bar_scales_discretize.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/interactive_index_chart.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/interactive_overview_detail.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/line.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/examples/arc_pie_pyramid.html
# Added 1 sections 0 categories
# Enrich table of contents vega-lite-docs/tutorials/streaming.html
# Added 0 sections 0 categories
# Enrich table of contents vega-lite-docs/tutorials/figures.html
# Added 0 sections 5 categories
# Enrich table of contents vega-lite-docs/tutorials/getting_started.html
# Added 0 sections 7 categories
# Enrich table of contents vega-lite-docs/tutorials/explore.html
# Added 0 sections 0 categories

# %%
matches = glob.glob(f"vega-lite-docs/**/*.html", recursive=True)
if DEBUG:
    print('Files', len(matches))
for name in matches:    
    # https://stackoverflow.com/questions/5598524/can-i-remove-script-tags-with-beautifulsoup
    processed = remove_page_elements(name)
    
    with open(name, 'w') as fp:
        fp.write(processed)
# Out:
# Files 258
# removing sidebar from  vega-lite-docs/docs/sort.html
# removing sidebar from  vega-lite-docs/docs/legend.html
# removing sidebar from  vega-lite-docs/docs/mark.html
# removing sidebar from  vega-lite-docs/docs/size.html
# removing sidebar from  vega-lite-docs/docs/bin.html
# removing sidebar from  vega-lite-docs/docs/datum.html
# removing sidebar from  vega-lite-docs/docs/errorbar.html
# removing sidebar from  vega-lite-docs/docs/format.html
# removing sidebar from  vega-lite-docs/docs/text.html
# removing sidebar from  vega-lite-docs/docs/image.html
# removing sidebar from  vega-lite-docs/docs/density.html
# removing sidebar from  vega-lite-docs/docs/band.html
# removing sidebar from  vega-lite-docs/docs/window.html
# removing sidebar from  vega-lite-docs/docs/label.html
# removing sidebar from  vega-lite-docs/docs/index.html
# removing sidebar from  vega-lite-docs/docs/geoshape.html
# removing sidebar from  vega-lite-docs/docs/impute.html
# removing sidebar from  vega-lite-docs/docs/joinaggregate.html
# removing sidebar from  vega-lite-docs/docs/type.html
# removing sidebar from  vega-lite-docs/docs/composition.html
# removing sidebar from  vega-lite-docs/docs/transform.html
# removing sidebar from  vega-lite-docs/docs/parameter.html
# removing sidebar from  vega-lite-docs/docs/lookup.html
# removing sidebar from  vega-lite-docs/docs/calculate.html
# removing sidebar from  vega-lite-docs/docs/title.html
# removing sidebar from  vega-lite-docs/docs/bind.html
# removing sidebar from  vega-lite-docs/docs/selection.html
# removing sidebar from  vega-lite-docs/docs/point.html
# removing sidebar from  vega-lite-docs/docs/gradient.html
# removing sidebar from  vega-lite-docs/docs/repeat.html
# removing sidebar from  vega-lite-docs/docs/tick.html
# removing sidebar from  vega-lite-docs/docs/axis.html
# removing sidebar from  vega-lite-docs/docs/sample.html
# removing sidebar from  vega-lite-docs/docs/flatten.html
# removing sidebar from  vega-lite-docs/docs/aggregate.html
# removing sidebar from  vega-lite-docs/docs/bar.html
# removing sidebar from  vega-lite-docs/docs/data.html
# removing sidebar from  vega-lite-docs/docs/pivot.html
# removing sidebar from  vega-lite-docs/docs/predicate.html
# removing sidebar from  vega-lite-docs/docs/trail.html
# removing sidebar from  vega-lite-docs/docs/loess.html
# removing sidebar from  vega-lite-docs/docs/facet.html
# removing sidebar from  vega-lite-docs/docs/arc.html
# removing sidebar from  vega-lite-docs/docs/area.html
# removing sidebar from  vega-lite-docs/docs/circle.html
# removing sidebar from  vega-lite-docs/docs/quantile.html
# removing sidebar from  vega-lite-docs/docs/projection.html
# removing sidebar from  vega-lite-docs/docs/boxplot.html
# removing sidebar from  vega-lite-docs/docs/timeunit.html
# removing sidebar from  vega-lite-docs/docs/config.html
# removing sidebar from  vega-lite-docs/docs/rect.html
# removing sidebar from  vega-lite-docs/docs/condition.html
# removing sidebar from  vega-lite-docs/docs/types.html
# removing sidebar from  vega-lite-docs/docs/tooltip.html
# removing sidebar from  vega-lite-docs/docs/value.html
# removing sidebar from  vega-lite-docs/docs/fold.html
# removing sidebar from  vega-lite-docs/docs/field.html
# removing sidebar from  vega-lite-docs/docs/encoding.html
# removing sidebar from  vega-lite-docs/docs/datetime.html
# removing sidebar from  vega-lite-docs/docs/concat.html
# removing sidebar from  vega-lite-docs/docs/header.html
# removing sidebar from  vega-lite-docs/docs/square.html
# removing sidebar from  vega-lite-docs/docs/regression.html
# removing sidebar from  vega-lite-docs/docs/errorband.html
# removing sidebar from  vega-lite-docs/docs/spec.html
# removing sidebar from  vega-lite-docs/docs/filter.html
# removing sidebar from  vega-lite-docs/docs/scale.html
# removing sidebar from  vega-lite-docs/docs/layer.html
# removing sidebar from  vega-lite-docs/docs/rule.html
# removing sidebar from  vega-lite-docs/docs/stack.html
# removing sidebar from  vega-lite-docs/docs/line.html
# removing sidebar from  vega-lite-docs/docs/resolve.html

# %%
#!rsync -r ../vega-lite/site/_site/* ./vega-lite-docs

# %%
# Move HTML into the right directory
#!rsync -r ../vega-lite/site/_site/* ./vega-lite-docs
# exclude static data files since dash doesn't run a local fileserver
# !rsync -r ./vega-lite-docs/* $DOCSET_PATH \
     --exclude 'data/*.csv' --exclude 'data/*.arrow' --exclude 'data/*.json' --exclude 'data/*.tsv' \
     --exclude 'sitemap.xml' --exclude 'redirects.json' --exclude 'rollup.config.js' --exclude 'applications.html'

# %%
# Prepare to publish in adjacent user contribs repository
# tar --exclude='.DS_Store' -cvzf vega-lite.tgz vega-lite.docset
# cp vega-lite.tgz ../Dash-User-Contributions/docsets/Vega-Lite/
